# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid
import numpy as np
import matplotlib.image as mpimg

# %%
# Praproses - Gausian Noise
sdir = 'newtest/'
file_name = ''+sdir
resp = {}
#buat folder
if os.path.exists(file_name) == False:
    os.mkdir(''+sdir)

dir = "test/"
list_class = os.listdir(dir) 
total_class = len(list_class)
for i in range(total_class):

    folder = ""+sdir+list_class[i]
    if os.path.exists(folder) == False:
        os.mkdir(folder)
    list_data = os.listdir(dir+list_class[i]) 
    total_data = len(list_data)
    
    #loop data file in class
    for j in range(total_data):
        name = list_data[j]
        lokasi_save = folder+'/'+'1.jpg'
        lokasi_file = dir+list_class[i]+'/'+list_data[j]
        resp[j] = lokasi_file

    im1 = mpimg.imread(resp[0])
    im2 = mpimg.imread(resp[1])
    im3 = mpimg.imread(resp[2])
    im4 = mpimg.imread(resp[3])
    im5 = mpimg.imread(resp[4])

    fig = plt.figure(figsize=(15., 15.))
    grid = ImageGrid(fig, 111,  # similar to subplot(111)
                    nrows_ncols=(2, 3),  # creates 2x2 grid of axes
                    axes_pad=0.1,  # pad between axes in inch.
                    )

    for ax, im in zip(grid, [im1, im2, im3, im4,im5]):
        # Iterating over the grid returns the Axes.
        ax.imshow(im)

    plt.savefig(lokasi_save) 
    plt.clf()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12068/2065812259.py in <module>
#      41         ax.imshow(im)
#      42
# ---> 43     plt.savefig(lokasi_save)
#      44     plt.clf()
#      45
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     956 def savefig(*args, **kwargs):
#     957     fig = gcf()
# --> 958     res = fig.savefig(*args, **kwargs)
#     959     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     960     return res
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    3017                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3018
# -> 3019             self.canvas.print_figure(fname, **kwargs)
#    3020
#    3021     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2323                         orientation=orientation,
#    2324                         bbox_inches_restore=_bbox_inches_restore,
# -> 2325                         **kwargs)
#    2326             finally:
#    2327                 if bbox_inches and restore_bbox:
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1646             kwargs.pop(arg)
#    1647
# -> 1648         return func(*args, **kwargs)
#    1649
#    1650     return wrapper
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     410                          else deprecation_addendum,
#     411                 **kwargs)
# --> 412         return func(*inner_args, **inner_kwargs)
#     413
#     414     DECORATORS[wrapper] = decorator
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\backends\backend_agg.py in print_jpg(self, filename_or_obj, pil_kwargs, *args, **kwargs)
#     574         try:
#     575             self.figure.set_facecolor(a * np.array([r, g, b]) + 1 - a)
# --> 576             FigureCanvasAgg.draw(self)
#     577         finally:
#     578             self.figure.set_facecolor((r, g, b, a))
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     434              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435               else nullcontext()):
# --> 436             self.figure.draw(self.renderer)
#     437             # A GUI class may be need to update a window using this draw, so
#     438             # don't forget to call the superclass.
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      71     @wraps(draw)
#      72     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73         result = draw(artist, renderer, *args, **kwargs)
#      74         if renderer._rasterizing:
#      75             renderer.stop_rasterizing()
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    2809             self.patch.draw(renderer)
#    2810             mimage._draw_list_compositing_images(
# -> 2811                 renderer, self, artists, self.suppressComposite)
#    2812
#    2813             for sfig in self.subfigs:
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer)
#    3044                 artists.remove(spine)
#    3045
# -> 3046         self._update_title_position(renderer)
#    3047
#    3048         if not self.axison:
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\axes\_base.py in _update_title_position(self, renderer)
#    2984                 if (ax.xaxis.get_ticks_position() in ['top', 'unknown']
#    2985                         or ax.xaxis.get_label_position() == 'top'):
# -> 2986                     bb = ax.xaxis.get_tightbbox(renderer)
#    2987                 else:
#    2988                     bb = ax.get_window_extent(renderer)
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1103         ticks_to_draw = self._update_ticks()
#    1104
# -> 1105         self._update_label_position(renderer)
#    1106
#    1107         # go back to just this axis's tick labels
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\axis.py in _update_label_position(self, renderer)
#    2081         # get bounding boxes for this axis and any siblings
#    2082         # that have been set by `fig.align_xlabels()`
# -> 2083         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2084
#    2085         x, y = self.label.get_position()
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\axis.py in _get_tick_boxes_siblings(self, renderer)
#    1878         for ax in grouper.get_siblings(self.axes):
#    1879             axis = getattr(ax, f"{axis_name}axis")
# -> 1880             ticks_to_draw = axis._update_ticks()
#    1881             tlb, tlb2 = axis._get_tick_bboxes(ticks_to_draw, renderer)
#    1882             bboxes.extend(tlb)
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\axis.py in _update_ticks(self)
#    1043         the axes.  Return the list of ticks that will be drawn.
#    1044         """
# -> 1045         major_locs = self.get_majorticklocs()
#    1046         major_labels = self.major.formatter.format_ticks(major_locs)
#    1047         major_ticks = self.get_major_ticks(len(major_locs))
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\axis.py in get_majorticklocs(self)
#    1275     def get_majorticklocs(self):
#    1276         """Return this Axis' major tick locations in data coordinates."""
# -> 1277         return self.major.locator()
#    1278
#    1279     def get_minorticklocs(self):
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\ticker.py in __call__(self)
#    2112     def __call__(self):
#    2113         vmin, vmax = self.axis.get_view_interval()
# -> 2114         return self.tick_values(vmin, vmax)
#    2115
#    2116     def tick_values(self, vmin, vmax):
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\ticker.py in tick_values(self, vmin, vmax)
#    2120         vmin, vmax = mtransforms.nonsingular(
#    2121             vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2122         locs = self._raw_ticks(vmin, vmax)
#    2123
#    2124         prune = self._prune
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\ticker.py in _raw_ticks(self, vmin, vmax)
#    2059         if self._nbins == 'auto':
#    2060             if self.axis is not None:
# -> 2061                 nbins = np.clip(self.axis.get_tick_space(),
#    2062                                 max(1, self._min_n_ticks - 1), 9)
#    2063             else:
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\axis.py in get_tick_space(self)
#    2262         ends = mtransforms.Bbox.from_bounds(0, 0, 1, 1)
#    2263         ends = ends.transformed(self.axes.transAxes -
# -> 2264                                 self.figure.dpi_scale_trans)
#    2265         length = ends.width * 72
#    2266         # There is a heuristic here that the aspect ratio of tick text
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\transforms.py in transformed(self, transform)
#     491         pts = self.get_points()
#     492         ll, ul, lr = transform.transform(np.array(
# --> 493             [pts[0], [pts[0, 0], pts[1, 1]], [pts[1, 0], pts[0, 1]]]))
#     494         return Bbox([ll, [lr[0], ul[1]]])
#     495
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\transforms.py in transform(self, values)
#    1501
#    1502         # Transform the values
# -> 1503         res = self.transform_affine(self.transform_non_affine(values))
#    1504
#    1505         # Convert the result back to the shape of the input values.
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\transforms.py in transform_affine(self, points)
#    2417     def transform_affine(self, points):
#    2418         # docstring inherited
# -> 2419         return self.get_affine().transform(points)
#    2420
#    2421     def transform_non_affine(self, points):
#
# c:\Users\Gigabyte\anaconda3\envs\torch\lib\site-packages\matplotlib\transforms.py in get_affine(self)
#    2445         else:
#    2446             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
# -> 2447                                    self._a.get_affine().get_matrix()))
#    2448
#    2449     def inverted(self):
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
lokasi_save
# Out:
# 'newtest/YELLOW HEADED BLACKBIRD/1.jpg'
